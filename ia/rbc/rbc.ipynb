# %%
import pandas as pd

# %%
# Carregar o arquivo Excel enviado
file_path = 'data/library.xlsx'

# Ler o conteúdo do arquivo
excel_data = pd.ExcelFile(file_path)

# Verificar as planilhas disponíveis no arquivo
sheet_names = excel_data.sheet_names
sheet_names
# Out:
# ['Casos', 'Pesos']

# %%
# Carregar os dados da planilha "Casos"
casos_df = pd.read_excel(excel_data, sheet_name='Casos')

# Exibir as primeiras linhas da base de casos
casos_df.head()
# Out:
#   area damaged canker lesion         crop hist     date external decay  \
# 0    low-areas         brown       same-1st-yr  october   firm-and-dry
# 1    scattered         brown  same-lst-two-yrs   august   firm-and-dry
# 2    scattered           dna       same-1st-yr     july   firm-and-dry
# 3    scattered           dna       same-1st-yr     july   firm-and-dry
# 4    scattered         brown  same-lst-two-yrs  october   firm-and-dry
#
#   fruit spots fruiting bodies fruit pods germination hail  ...  seed  \
# 0         dna         present       norm     90-100%  yes  ...  norm
# 1         dna         present       norm      80-89%  yes  ...  norm
# 2         dna         present       norm      lt-80%  yes  ...  norm
# 3         dna         present       norm      80-89%  yes  ...  norm
# 4         dna         present       norm      lt-80%  yes  ...  norm
#
#   seed discolor seed size   seed tmt    severity shriveling    stem  \
# 0        absent      norm       none  pot-severe     absent  abnorm
# 1        absent      norm  fungicide      severe     absent  abnorm
# 2        absent      norm  fungicide      severe     absent  abnorm
# 3        absent      norm       none      severe     absent  abnorm
# 4        absent      norm       none  pot-severe     absent  abnorm
#
#     stem cankers  temp              objective
# 0  above-sec-nde  norm  diaporthe-stem-canker
# 1  above-sec-nde  norm  diaporthe-stem-canker
# 2  above-sec-nde  norm  diaporthe-stem-canker
# 3  above-sec-nde  norm  diaporthe-stem-canker
# 4  above-sec-nde  norm  diaporthe-stem-canker
#
# [5 rows x 36 columns]

# %%
# Função para gerar a tabela de similaridade para um atributo
def generate_similarity_table(attribute):
    clean_values = casos_df[attribute].replace('dna', pd.NA).dropna().unique()
    sorted_values = sorted(clean_values)
    
    # Criar a tabela de similaridade
    table = pd.DataFrame(index=sorted_values, columns=sorted_values)
    
    for i, val1 in enumerate(sorted_values):
        for j, val2 in enumerate(sorted_values):
            table.loc[val1, val2] = 1 - abs(i - j) / (len(sorted_values) - 1)
    
    return table

# Selecionar os demais atributos para gerar as tabelas de similaridade
attributes = casos_df.columns

# Dicionário para armazenar todas as tabelas de similaridade
similarity_tables = {}

# Gerar as tabelas de similaridade para todos os atributos
for attribute in attributes:
    similarity_tables[attribute] = generate_similarity_table(attribute)

# Exibir um exemplo de tabela para outro atributo, como "canker lesion"
similarity_tables
# Out:
# {'area damaged':             low-areas scattered unknown upper-areas whole-field
#  low-areas         1.0      0.75     0.5        0.25         0.0
#  scattered        0.75       1.0    0.75         0.5        0.25
#  unknown           0.5      0.75     1.0        0.75         0.5
#  upper-areas      0.25       0.5    0.75         1.0        0.75
#  whole-field       0.0      0.25     0.5        0.75         1.0,
#  'canker lesion':                  brown dk-brown-blk       tan   unknown
#  brown              1.0     0.666667  0.333333       0.0
#  dk-brown-blk  0.666667          1.0  0.666667  0.333333
#  tan           0.333333     0.666667       1.0  0.666667
#  unknown            0.0     0.333333  0.666667       1.0,
#  'crop hist':                  diff-1st-year same-1st-yr same-lst-sev-yrs same-lst-two-yrs  \
#  diff-1st-year              1.0        0.75              0.5             0.25
#  same-1st-yr               0.75         1.0             0.75              0.5
#  same-lst-sev-yrs           0.5        0.75              1.0             0.75
#  same-lst-two-yrs          0.25         0.5             0.75              1.0
#  unknown                    0.0        0.25              0.5             0.75
#
#                   unknown
#  diff-1st-year        0.0
#  same-1st-yr         0.25
#  same-lst-sev-yrs     0.5
#  same-lst-two-yrs    0.75
#  unknown              1.0  ,
#  'date':               april    august      july      june       may   october  \
#  april           1.0  0.857143  0.714286  0.571429  0.428571  0.285714
#  august     0.857143       1.0  0.857143  0.714286  0.571429  0.428571
#  july       0.714286  0.857143       1.0  0.857143  0.714286  0.571429
#  june       0.571429  0.714286  0.857143       1.0  0.857143  0.714286
#  may        0.428571  0.571429  0.714286  0.857143       1.0  0.857143
#  october    0.285714  0.428571  0.571429  0.714286  0.857143       1.0
#  september  0.142857  0.285714  0.428571  0.571429  0.714286  0.857143
#  unknown         0.0  0.142857  0.285714  0.428571  0.571429  0.714286
#
#            september   unknown
#  april      0.142857       0.0
#  august     0.285714  0.142857
#  july       0.428571  0.285714
#  june       0.571429  0.428571
#  may        0.714286  0.571429
#  october    0.857143  0.714286
#  september       1.0  0.857143
#  unknown    0.857143       1.0  ,
#  'external decay':              absent firm-and-dry unknown
#  absent          1.0          0.5     0.0
#  firm-and-dry    0.5          1.0     0.5
#  unknown         0.0          0.5     1.0,
#  'fruit spots':                       absent brown-w/blk-specks   colored   unknown
#  absent                   1.0           0.666667  0.333333       0.0
#  brown-w/blk-specks  0.666667                1.0  0.666667  0.333333
#  colored             0.333333           0.666667       1.0  0.666667
#  unknown                  0.0           0.333333  0.666667       1.0,
#  'fruiting bodies':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'fruit pods':              diseased few-present      norm   unknown
#  diseased          1.0    0.666667  0.333333       0.0
#  few-present  0.666667         1.0  0.666667  0.333333
#  norm         0.333333    0.666667       1.0  0.666667
#  unknown           0.0    0.333333  0.666667       1.0,
#  'germination':         80-89 % 80-89% 90-100% lt-80% unknown
#  80-89 %     1.0   0.75     0.5   0.25     0.0
#  80-89%     0.75    1.0    0.75    0.5    0.25
#  90-100%     0.5   0.75     1.0   0.75     0.5
#  lt-80%     0.25    0.5    0.75    1.0    0.75
#  unknown     0.0   0.25     0.5   0.75     1.0,
#  'hail':           no unknown  yes
#  no       1.0     0.5  0.0
#  unknown  0.5     1.0  0.5
#  yes      0.0     0.5  1.0,
#  'int discolor':             Black     brown      none   unknown
#  Black         1.0  0.666667  0.333333       0.0
#  brown    0.666667       1.0  0.666667  0.333333
#  none     0.333333  0.666667       1.0  0.666667
#  unknown       0.0  0.333333  0.666667       1.0,
#  'leaf malf':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'leaf mild':            Lower-surf Upper-surf    absent   unknown
#  Lower-surf        1.0   0.666667  0.333333       0.0
#  Upper-surf   0.666667        1.0  0.666667  0.333333
#  absent       0.333333   0.666667       1.0  0.666667
#  unknown           0.0   0.333333  0.666667       1.0,
#  'leaf shread':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'leafspots halo':                    absent no-yellow-halos   unknown yellow-halos
#  absent                1.0        0.666667  0.333333          0.0
#  no-yellow-halos  0.666667             1.0  0.666667     0.333333
#  unknown          0.333333        0.666667       1.0     0.666667
#  yellow-halos          0.0        0.333333  0.666667          1.0,
#  'leafspot size':         gt-1/8 lt-1/8 unknown
#  gt-1/8     1.0    0.5     0.0
#  lt-1/8     0.5    1.0     0.5
#  unknown    0.0    0.5     1.0,
#  'leafspots marg':             no-w-s-marg unknown w-s-marg
#  no-w-s-marg         1.0     0.5      0.0
#  unknown             0.5     1.0      0.5
#  w-s-marg            0.0     0.5      1.0,
#  'leaves':        abnorm norm
#  abnorm    1.0  0.0
#  norm      0.0  1.0,
#  'lodging':           no unknown  yes
#  no       1.0     0.5  0.0
#  unknown  0.5     1.0  0.5
#  yes      0.0     0.5  1.0,
#  'mold growth':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'mycelium':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'plant growth':         abnorm norm unknown
#  abnorm     1.0  0.5     0.0
#  norm       0.5  1.0     0.5
#  unknown    0.0  0.5     1.0,
#  'plant stand':           lt-normal normal unknown
#  lt-normal       1.0    0.5     0.0
#  normal          0.5    1.0     0.5
#  unknown         0.0    0.5     1.0,
#  'precip':           gt-normal lt-normal    normal   unknown
#  gt-normal       1.0  0.666667  0.333333       0.0
#  lt-normal  0.666667       1.0  0.666667  0.333333
#  normal     0.333333  0.666667       1.0  0.666667
#  unknown         0.0  0.333333  0.666667       1.0,
#  'roots':             galls-cysts      norm    rotted   unknown
#  galls-cysts         1.0  0.666667  0.333333       0.0
#  norm           0.666667       1.0  0.666667  0.333333
#  rotted         0.333333  0.666667       1.0  0.666667
#  unknown             0.0  0.333333  0.666667       1.0,
#  'sclerotia':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'seed':         abnorm norm unknown
#  abnorm     1.0  0.5     0.0
#  norm       0.5  1.0     0.5
#  unknown    0.0  0.5     1.0,
#  'seed discolor':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'seed size':         lt-norm norm unknown
#  lt-norm     1.0  0.5     0.0
#  norm        0.5  1.0     0.5
#  unknown     0.0  0.5     1.0,
#  'seed tmt':              Outros fungicide      none   unknown
#  Outros          1.0  0.666667  0.333333       0.0
#  fungicide  0.666667       1.0  0.666667  0.333333
#  none       0.333333  0.666667       1.0  0.666667
#  unknown         0.0  0.333333  0.666667       1.0,
#  'severity':                Minor pot-severe    severe   unknown
#  Minor            1.0   0.666667  0.333333       0.0
#  pot-severe  0.666667        1.0  0.666667  0.333333
#  severe      0.333333   0.666667       1.0  0.666667
#  unknown          0.0   0.333333  0.666667       1.0,
#  'shriveling':         absent present unknown
#  absent     1.0     0.5     0.0
#  present    0.5     1.0     0.5
#  unknown    0.0     0.5     1.0,
#  'stem':         abnorm norm unknown
#  abnorm     1.0  0.5     0.0
#  norm       0.5  1.0     0.5
#  unknown    0.0  0.5     1.0,
#  'stem cankers':               above-sec-nde above-soil absent below-soil unknown
#  above-sec-nde           1.0       0.75    0.5       0.25     0.0
#  above-soil             0.75        1.0   0.75        0.5    0.25
#  absent                  0.5       0.75    1.0       0.75     0.5
#  below-soil             0.25        0.5   0.75        1.0    0.75
#  unknown                 0.0       0.25    0.5       0.75     1.0,
#  'temp':           gt-norm   lt-norm      norm   unknown
#  gt-norm       1.0  0.666667  0.333333       0.0
#  lt-norm  0.666667       1.0  0.666667  0.333333
#  norm     0.333333  0.666667       1.0  0.666667
#  unknown       0.0  0.333333  0.666667       1.0,
#  'objective':                             2-4-d-injury alternarialeaf-spot anthracnose  \
#  2-4-d-injury                         1.0            0.944444    0.888889
#  alternarialeaf-spot             0.944444                 1.0    0.944444
#  anthracnose                     0.888889            0.944444         1.0
#  bacterial-blight                0.833333            0.888889    0.944444
#  bacterial-pustule               0.777778            0.833333    0.888889
#  brown-spot                      0.722222            0.777778    0.833333
#  brown-stem-rot                  0.666667            0.722222    0.777778
#  charcoal-rot                    0.611111            0.666667    0.722222
#  cyst-nematode                   0.555556            0.611111    0.666667
#  diaporthe-pod-&-stem-blight          0.5            0.555556    0.611111
#  diaporthe-stem-canker           0.444444                 0.5    0.555556
#  downy-mildew                    0.388889            0.444444         0.5
#  frog-eye-leaf-spot              0.333333            0.388889    0.444444
#  herbicide-injury                0.277778            0.333333    0.388889
#  phyllosticta-leaf-spot          0.222222            0.277778    0.333333
#  phytophthora-rot                0.166667            0.222222    0.277778
#  powdery-mildew                  0.111111            0.166667    0.222222
#  purple-seed-stain               0.055556            0.111111    0.166667
#  rhizoctonia-root-rot                 0.0            0.055556    0.111111
#
#                              bacterial-blight bacterial-pustule brown-spot  \
#  2-4-d-injury                        0.833333          0.777778   0.722222
#  alternarialeaf-spot                 0.888889          0.833333   0.777778
#  anthracnose                         0.944444          0.888889   0.833333
#  bacterial-blight                         1.0          0.944444   0.888889
#  bacterial-pustule                   0.944444               1.0   0.944444
#  brown-spot                          0.888889          0.944444        1.0
#  brown-stem-rot                      0.833333          0.888889   0.944444
#  charcoal-rot                        0.777778          0.833333   0.888889
#  cyst-nematode                       0.722222          0.777778   0.833333
#  diaporthe-pod-&-stem-blight         0.666667          0.722222   0.777778
#  diaporthe-stem-canker               0.611111          0.666667   0.722222
#  downy-mildew                        0.555556          0.611111   0.666667
#  frog-eye-leaf-spot                       0.5          0.555556   0.611111
#  herbicide-injury                    0.444444               0.5   0.555556
#  phyllosticta-leaf-spot              0.388889          0.444444        0.5
#  phytophthora-rot                    0.333333          0.388889   0.444444
#  powdery-mildew                      0.277778          0.333333   0.388889
#  purple-seed-stain                   0.222222          0.277778   0.333333
#  rhizoctonia-root-rot                0.166667          0.222222   0.277778
#
#                              brown-stem-rot charcoal-rot cyst-nematode  \
#  2-4-d-injury                      0.666667     0.611111      0.555556
#  alternarialeaf-spot               0.722222     0.666667      0.611111
#  anthracnose                       0.777778     0.722222      0.666667
#  bacterial-blight                  0.833333     0.777778      0.722222
#  bacterial-pustule                 0.888889     0.833333      0.777778
#  brown-spot                        0.944444     0.888889      0.833333
#  brown-stem-rot                         1.0     0.944444      0.888889
#  charcoal-rot                      0.944444          1.0      0.944444
#  cyst-nematode                     0.888889     0.944444           1.0
#  diaporthe-pod-&-stem-blight       0.833333     0.888889      0.944444
#  diaporthe-stem-canker             0.777778     0.833333      0.888889
#  downy-mildew                      0.722222     0.777778      0.833333
#  frog-eye-leaf-spot                0.666667     0.722222      0.777778
#  herbicide-injury                  0.611111     0.666667      0.722222
#  phyllosticta-leaf-spot            0.555556     0.611111      0.666667
#  phytophthora-rot                       0.5     0.555556      0.611111
#  powdery-mildew                    0.444444          0.5      0.555556
#  purple-seed-stain                 0.388889     0.444444           0.5
#  rhizoctonia-root-rot              0.333333     0.388889      0.444444
#
#                              diaporthe-pod-&-stem-blight diaporthe-stem-canker  \
#  2-4-d-injury                                        0.5              0.444444
#  alternarialeaf-spot                            0.555556                   0.5
#  anthracnose                                    0.611111              0.555556
#  bacterial-blight                               0.666667              0.611111
#  bacterial-pustule                              0.722222              0.666667
#  brown-spot                                     0.777778              0.722222
#  brown-stem-rot                                 0.833333              0.777778
#  charcoal-rot                                   0.888889              0.833333
#  cyst-nematode                                  0.944444              0.888889
#  diaporthe-pod-&-stem-blight                         1.0              0.944444
#  diaporthe-stem-canker                          0.944444                   1.0
#  downy-mildew                                   0.888889              0.944444
#  frog-eye-leaf-spot                             0.833333              0.888889
#  herbicide-injury                               0.777778              0.833333
#  phyllosticta-leaf-spot                         0.722222              0.777778
#  phytophthora-rot                               0.666667              0.722222
#  powdery-mildew                                 0.611111              0.666667
#  purple-seed-stain                              0.555556              0.611111
#  rhizoctonia-root-rot                                0.5              0.555556
#
#                              downy-mildew frog-eye-leaf-spot herbicide-injury  \
#  2-4-d-injury                    0.388889           0.333333         0.277778
#  alternarialeaf-spot             0.444444           0.388889         0.333333
#  anthracnose                          0.5           0.444444         0.388889
#  bacterial-blight                0.555556                0.5         0.444444
#  bacterial-pustule               0.611111           0.555556              0.5
#  brown-spot                      0.666667           0.611111         0.555556
#  brown-stem-rot                  0.722222           0.666667         0.611111
#  charcoal-rot                    0.777778           0.722222         0.666667
#  cyst-nematode                   0.833333           0.777778         0.722222
#  diaporthe-pod-&-stem-blight     0.888889           0.833333         0.777778
#  diaporthe-stem-canker           0.944444           0.888889         0.833333
#  downy-mildew                         1.0           0.944444         0.888889
#  frog-eye-leaf-spot              0.944444                1.0         0.944444
#  herbicide-injury                0.888889           0.944444              1.0
#  phyllosticta-leaf-spot          0.833333           0.888889         0.944444
#  phytophthora-rot                0.777778           0.833333         0.888889
#  powdery-mildew                  0.722222           0.777778         0.833333
#  purple-seed-stain               0.666667           0.722222         0.777778
#  rhizoctonia-root-rot            0.611111           0.666667         0.722222
#
#                              phyllosticta-leaf-spot phytophthora-rot  \
#  2-4-d-injury                              0.222222         0.166667
#  alternarialeaf-spot                       0.277778         0.222222
#  anthracnose                               0.333333         0.277778
#  bacterial-blight                          0.388889         0.333333
#  bacterial-pustule                         0.444444         0.388889
#  brown-spot                                     0.5         0.444444
#  brown-stem-rot                            0.555556              0.5
#  charcoal-rot                              0.611111         0.555556
#  cyst-nematode                             0.666667         0.611111
#  diaporthe-pod-&-stem-blight               0.722222         0.666667
#  diaporthe-stem-canker                     0.777778         0.722222
#  downy-mildew                              0.833333         0.777778
#  frog-eye-leaf-spot                        0.888889         0.833333
#  herbicide-injury                          0.944444         0.888889
#  phyllosticta-leaf-spot                         1.0         0.944444
#  phytophthora-rot                          0.944444              1.0
#  powdery-mildew                            0.888889         0.944444
#  purple-seed-stain                         0.833333         0.888889
#  rhizoctonia-root-rot                      0.777778         0.833333
#
#                              powdery-mildew purple-seed-stain  \
#  2-4-d-injury                      0.111111          0.055556
#  alternarialeaf-spot               0.166667          0.111111
#  anthracnose                       0.222222          0.166667
#  bacterial-blight                  0.277778          0.222222
#  bacterial-pustule                 0.333333          0.277778
#  brown-spot                        0.388889          0.333333
#  brown-stem-rot                    0.444444          0.388889
#  charcoal-rot                           0.5          0.444444
#  cyst-nematode                     0.555556               0.5
#  diaporthe-pod-&-stem-blight       0.611111          0.555556
#  diaporthe-stem-canker             0.666667          0.611111
#  downy-mildew                      0.722222          0.666667
#  frog-eye-leaf-spot                0.777778          0.722222
#  herbicide-injury                  0.833333          0.777778
#  phyllosticta-leaf-spot            0.888889          0.833333
#  phytophthora-rot                  0.944444          0.888889
#  powdery-mildew                         1.0          0.944444
#  purple-seed-stain                 0.944444               1.0
#  rhizoctonia-root-rot              0.888889          0.944444
#
#                              rhizoctonia-root-rot
#  2-4-d-injury                                 0.0
#  alternarialeaf-spot                     0.055556
#  anthracnose                             0.111111
#  bacterial-blight                        0.166667
#  bacterial-pustule                       0.222222
#  brown-spot                              0.277778
#  brown-stem-rot                          0.333333
#  charcoal-rot                            0.388889
#  cyst-nematode                           0.444444
#  diaporthe-pod-&-stem-blight                  0.5
#  diaporthe-stem-canker                   0.555556
#  downy-mildew                            0.611111
#  frog-eye-leaf-spot                      0.666667
#  herbicide-injury                        0.722222
#  phyllosticta-leaf-spot                  0.777778
#  phytophthora-rot                        0.833333
#  powdery-mildew                          0.888889
#  purple-seed-stain                       0.944444
#  rhizoctonia-root-rot                         1.0  }

# %%
# Carregar o arquivo "input.xlsx" enviado pelo usuário
input_file_path = 'data/input.xlsx'

# Ler os dados da nova tabela de entrada (input.xlsx)
input_data = pd.ExcelFile(input_file_path)

# Verificar as planilhas disponíveis no arquivo
input_sheet_names = input_data.sheet_names
input_sheet_names
# Out:
# ['Casos', 'Pesos']

# %%
# Loop para exibir todas as tabelas de similaridade com seus nomes
for atributo, tabela in similarity_tables.items():
    print(f"Tabela de Similaridade para o atributo: {atributo}")
    print(atributo)
    print("\n")
# Out:
# Tabela de Similaridade para o atributo: area damaged
# area damaged
#
#
# Tabela de Similaridade para o atributo: canker lesion
# canker lesion
#
#
# Tabela de Similaridade para o atributo: crop hist
# crop hist
#
#
# Tabela de Similaridade para o atributo: date
# date
#
#
# Tabela de Similaridade para o atributo: external decay
# external decay
#
#
# Tabela de Similaridade para o atributo: fruit spots
# fruit spots
#
#
# Tabela de Similaridade para o atributo: fruiting bodies
# fruiting bodies
#
#
# Tabela de Similaridade para o atributo: fruit pods
# fruit pods
#
#
# Tabela de Similaridade para o atributo: germination
# germination
#
#
# Tabela de Similaridade para o atributo: hail
# hail
#
#
# Tabela de Similaridade para o atributo: int discolor
# int discolor
#
#
# Tabela de Similaridade para o atributo: leaf malf
# leaf malf
#
#
# Tabela de Similaridade para o atributo: leaf mild
# leaf mild
#
#
# Tabela de Similaridade para o atributo: leaf shread
# leaf shread
#
#
# Tabela de Similaridade para o atributo: leafspots halo
# leafspots halo
#
#
# Tabela de Similaridade para o atributo: leafspot size
# leafspot size
#
#
# Tabela de Similaridade para o atributo: leafspots marg
# leafspots marg
#
#
# Tabela de Similaridade para o atributo: leaves
# leaves
#
#
# Tabela de Similaridade para o atributo: lodging
# lodging
#
#
# Tabela de Similaridade para o atributo: mold growth
# mold growth
#
#
# Tabela de Similaridade para o atributo: mycelium
# mycelium
#
#
# Tabela de Similaridade para o atributo: plant growth
# plant growth
#
#
# Tabela de Similaridade para o atributo: plant stand
# plant stand
#
#
# Tabela de Similaridade para o atributo: precip
# precip
#
#
# Tabela de Similaridade para o atributo: roots
# roots
#
#
# Tabela de Similaridade para o atributo: sclerotia
# sclerotia
#
#
# Tabela de Similaridade para o atributo: seed
# seed
#
#
# Tabela de Similaridade para o atributo: seed discolor
# seed discolor
#
#
# Tabela de Similaridade para o atributo: seed size
# seed size
#
#
# Tabela de Similaridade para o atributo: seed tmt
# seed tmt
#
#
# Tabela de Similaridade para o atributo: severity
# severity
#
#
# Tabela de Similaridade para o atributo: shriveling
# shriveling
#
#
# Tabela de Similaridade para o atributo: stem
# stem
#
#
# Tabela de Similaridade para o atributo: stem cankers
# stem cankers
#
#
# Tabela de Similaridade para o atributo: temp
# temp
#
#
# Tabela de Similaridade para o atributo: objective
# objective

# %%
import pandas as pd

# Carregar os arquivos
base_casos = pd.read_excel('data/library.xlsx', sheet_name='Casos')
input_casos = pd.read_excel('data/input.xlsx')

# Função para calcular a similaridade de um novo caso com a base
def calcular_similaridade(novo_caso, base_caso, similaridade_tables):
    total_similaridade = 0
    num_atributos = len(novo_caso)
    
    for atributo in novo_caso.index:
        if atributo in similaridade_tables:
            tabela_similaridade = similaridade_tables[atributo]
            valor_novo = novo_caso[atributo]
            valor_base = base_caso[atributo]
            
            if valor_novo in tabela_similaridade.index and valor_base in tabela_similaridade.columns:
                similaridade = tabela_similaridade.loc[valor_novo, valor_base]
                total_similaridade += similaridade
    
    return total_similaridade / num_atributos

# Função principal para calcular a pontuação final e valor objetivo
def calcular_valor_objetivo(input_casos, base_casos, similaridade_tables):
    resultados = []
    
    # Criar coluna 'Caso' se não existir
    if 'Caso' not in input_casos.columns:
        input_casos['Caso'] = pd.NA  # Ou defina um valor padrão que desejar

    # Criar coluna 'objective' se não existir
    if 'objective' not in base_casos.columns:
        base_casos['objective'] = pd.NA  # Ou defina um valor padrão que desejar

    for idx, novo_caso in input_casos.iterrows():
        melhor_caso = None
        maior_similaridade = -1
        valor_objetivo = pd.NA  # Inicializando como nulo

        for _, base_caso in base_casos.iterrows():
            similaridade = calcular_similaridade(novo_caso, base_caso, similaridade_tables)

            if similaridade > maior_similaridade:
                maior_similaridade = similaridade
                melhor_caso = base_caso
                valor_objetivo = base_caso.get('objective', pd.NA)  # Obter o valor objetivo, se existir

        resultados.append({
            'Caso': novo_caso.get('Caso', pd.NA),  # Preencher se já existir
            'Melhor Casos': melhor_caso.get('Caso', pd.NA) if melhor_caso is not None else pd.NA,
            'Pontuação': maior_similaridade,
            'Valor Objetivo': valor_objetivo
        })

    return pd.DataFrame(resultados)



# Aqui você passaria as tabelas de similaridade geradas anteriormente
# Supondo que você já tenha as tabelas de similaridade geradas para cada atributo:
similaridade_tables = {
    'area damaged': similarity_tables['area damaged'],
    'canker lesion': similarity_tables['canker lesion'],
    'crop hist': similarity_tables['crop hist'],
    'date': similarity_tables['date'],
    'external decay': similarity_tables['external decay'],
    'fruit spots': similarity_tables['fruit spots'],
    'fruiting bodies': similarity_tables['fruiting bodies'],
    'fruit pods': similarity_tables['fruit pods'],
    'germination': similarity_tables['germination'],
    'hail': similarity_tables['hail'],
    'leaf mild': similarity_tables['leaf mild'],
    'leafspots halo': similarity_tables['leafspots halo'],
    'leafspots marg': similarity_tables['leafspots marg'],
    'lodging': similarity_tables['lodging'],
    'mycelium': similarity_tables['mycelium'],
    'plant stand': similarity_tables['plant stand'],
    'precip': similarity_tables['precip'],
    'roots': similarity_tables['roots'],
    'sclerotia': similarity_tables['sclerotia'],
    'seed': similarity_tables['seed'],
    'seed discolor': similarity_tables['seed discolor'],
    'seed size': similarity_tables['seed size'],
    'seed tmt': similarity_tables['seed tmt'],
    'severity': similarity_tables['severity'],
    'shriveling': similarity_tables['shriveling'],
    'stem': similarity_tables['stem'],
    'stem cankers': similarity_tables['stem cankers'],
    'temp': similarity_tables['temp']
}

# Você pode então passar esse dicionário para a função `calcular_valor_objetivo`:
resultados = calcular_valor_objetivo(input_casos, base_casos, similaridade_tables)
print(resultados)
# Out:
# Defina a faixa de pontuação que deseja buscar:
# Digite o valor inferior da faixa (ex: 0.1 para 10%):  0.1
# Digite o valor superior da faixa (ex: 0.2 para 20%):  0.5
