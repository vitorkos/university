# %%
import numpy as np

# %%
v = np.array([1,2,3,4])

# %%
v
# Out:
# array([1, 2, 3, 4])

# %%
type(v)
# Out:
# numpy.ndarray

# %%
lista = [22, 5, 21, 7]

# %%
v1 = np.array(lista)

# %%
v1
# Out:
# array([22,  5, 21,  7])

# %% [markdown]
# ##Representação vetorial (Base canônica)

# %%
e1 = np.array((1, 0, 0))
e2 = np.array([0, 1, 0])
e3 = np.array([0, 0, 1])

# %%
e1
# Out:
# array([1, 0, 0])
