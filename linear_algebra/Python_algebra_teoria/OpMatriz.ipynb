# %%
  import numpy as np

# %%
A = np.matrix('1,2,3;4,5,6;7,8,9')
B = np.matrix('4,5,8;7,4,8')
C = np.matrix('9,8,7;6,5,4;3,2,1')
print(A)
print(B)
print(C)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# [[4 5 8]
#  [7 4 8]]
# [[9 8 7]
#  [6 5 4]
#  [3 2 1]]

# %%
#Soma 
S = A+B
print(S)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-bc69ddd0baeb> in <module>()
#       1 #Soma
# ----> 2 S = A+B
#       3 print(S)
#
# ValueError: operands could not be broadcast together with shapes (3,3) (2,3)

# %%
#soma de linhas

# %%
L = A[0,0] + B[0,0]

# %%
L
# Out:
# 5

# %%
L1 = A[0,:] + B[0,:]
print(L1)
# Out:
# [[ 5  7 11]]

# %%
L2 = A[2,:] + B[1,:]
print(L2)
# Out:
# [[14 12 17]]

# %%
S = A + C
print(S)
# Out:
# [[10 10 10]
#  [10 10 10]
#  [10 10 10]]

# %%
Sub = A - C
print(Sub)
# Out:
# [[-8 -6 -4]
#  [-2  0  2]
#  [ 4  6  8]]

# %%
#Multiplicação de Matrizes
m = A*C
print(m)
# Out:
# [[ 30  24  18]
#  [ 84  69  54]
#  [138 114  90]]

# %%
#multiplicação por um escalar
k = 2
print(k*B)
# Out:
# [[ 8 10 16]
#  [14  8 16]]

# %%
#Divisão de Matrizes
D1 = A/C

# %%
D1
# Out:
# matrix([[0.11111111, 0.25      , 0.42857143],
#         [0.66666667, 1.        , 1.5       ],
#         [2.33333333, 4.        , 9.        ]])

# %%
#Multiplicação Matricial
F = C.dot(A)

# %%
F
# Out:
# matrix([[ 90, 114, 138],
#         [ 54,  69,  84],
#         [ 18,  24,  30]])

# %%
F1 = A.dot(C)
print(F1)
# Out:
# [[ 30  24  18]
#  [ 84  69  54]
#  [138 114  90]]

# %%
F12 = A[0,:].dot(C[:,1])
print(F12)
# Out:
# [[24]]
