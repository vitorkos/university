# %% [markdown]
# Implementação da Solução de um sistema triangular superior

# %%
def substituicoes_retroativas(A,b):
# Out:
#   File "<ipython-input-3-d51579c85375>", line 1
#     def substituicoes_retroativas(A,b):
#                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
n = len(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d5b79c81cc1b> in <module>()
# ----> 1 n = len(A)
#
# NameError: name 'A' is not defined

# %%
x = n * [0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a8563e83f40a> in <module>()
# ----> 1 x = n * [0]
#
# NameError: name 'n' is not defined
