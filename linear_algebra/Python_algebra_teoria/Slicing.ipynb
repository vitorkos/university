# %%
import numpy as np

# %%
A = np.matrix('1,2,3;4,5,6;7,8,9')

# %%
A
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
A.shape
# Out:
# (3, 3)

# %%
#slicing
A[:]
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %% [markdown]
# Não pode esquecer da indexação do python - começa em zero

# %%
A[2,1]
# Out:
# 8

# %%
A [1,:]
# Out:
# matrix([[4, 5, 6]])

# %%
A[:,0]
# Out:
# matrix([[1],
#         [4],
#         [7]])

# %%
B = A

# %%
B
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
B[1,2] = 77

# %%
B
# Out:
# matrix([[ 1,  2,  3],
#         [ 4,  5, 77],
#         [ 7,  8,  9]])

# %%
A
# Out:
# matrix([[ 1,  2,  3],
#         [ 4,  5, 77],
#         [ 7,  8,  9]])

# %%
#Cópia de Matrizes
C = B.copy()

# %%
C
# Out:
# matrix([[ 1,  2,  3],
#         [ 4,  5, 77],
#         [ 7,  8,  9]])

# %%
C[2,2]= 14

# %%
C
# Out:
# matrix([[ 1,  2,  3],
#         [ 4,  5, 77],
#         [ 7,  8, 14]])

# %%
B
# Out:
# matrix([[ 1,  2,  3],
#         [ 4,  5, 77],
#         [ 7,  8,  9]])
