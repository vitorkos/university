# %%
import numpy as np

# %%
A = np.array([[1,2,3],[2,8,4],[3,4,5]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [2, 8, 4],
#        [3, 4, 5]])

# %%
np.transpose(A)
# Out:
# array([[1, 2, 3],
#        [2, 8, 4],
#        [3, 4, 5]])

# %%
B = np.matrix ('1,2,3;4,5,6;7,8,9')

# %%
B
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
np.transpose(B)
# Out:
# matrix([[1, 4, 7],
#         [2, 5, 8],
#         [3, 6, 9]])

# %%
C = np.matrix('1,2,3;4,5,6')

# %%
C
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6]])

# %%
C.T
# Out:
# matrix([[1, 4],
#         [2, 5],
#         [3, 6]])
