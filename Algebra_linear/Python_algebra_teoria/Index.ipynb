# %%
import numpy as np

# %%
x = [1,2,3,4,5]  #vetor

# %%
type(x)
# Out:
# list

# %%
vx = np.array(x)

# %%
vx
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# ### A indexacção em Phyton se inicia em 0 e não em 1

# %%
len(vx)
# Out:
# 5

# %%
pos_3 = vx[2]

# %%
pos_3
# Out:
# 3

# %%
pos_4 = vx[3]

# %%
pos_4
# Out:
# 4
