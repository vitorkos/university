# %% [markdown]
# #Título 1
# ##Título 2
# ###Título 3
#
# -Carros
#   - Gol
#     - 4 portas
#   - Fox
#     - 2 portas
#   - Palio

# %%
print('Olá Mundo')
# Out:
# Olá Mundo

# %%
# Esta é uma variável
a = 22

# %%
print('teste 3')
# Out:
# teste 3
