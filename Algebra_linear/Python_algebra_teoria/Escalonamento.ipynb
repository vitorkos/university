# %%
import numpy as np

# %%
A = np.matrix('3,2,5, 4;12, 5,3,11; 1,3,5, 8')

# %%
A
# Out:
# matrix([[ 3,  2,  5,  4],
#         [12,  5,  3, 11],
#         [ 1,  3,  5,  8]])

# %%
A1 = A.copy()

# %%
A1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4a5b95edbea7> in <module>()
# ----> 1 A1
#
# NameError: name 'A1' is not defined

# %%
#troca de linhas
A1[0,0]=1
A1[0,1]= 3
A1[0,2] = 5
A1[0,3]= 8
A1[2,0] = 3
A1[2,1]= 2
A1[2,2]=5
A1[2,3] = 4

# %%
A1
# Out:
# matrix([[ 1,  3,  5,  8],
#         [12,  5,  3, 11],
#         [ 3,  2,  5,  4]])

# %%
A2 = A1.copy()

# %%
A2
# Out:
# matrix([[ 1,  3,  5,  8],
#         [12,  5,  3, 11],
#         [ 3,  2,  5,  4]])

# %%
A2[1,:] = A2[1,:] - 12*A2[0,:]
print(A2)
# Out:
# [[  1   3   5   8]
#  [  0 -31 -57 -85]
#  [  3   2   5   4]]

# %%
A2[2,:] = A2[2,:] - 3*A2[0,:]
print(A2)
# Out:
# [[  1   3   5   8]
#  [  0 -31 -57 -85]
#  [  0  -7 -10 -20]]

# %%
A3 = A2.copy()

# %%
A3[2,:] = -31*A3[2,:] + 7*A2[1,:]
print(A3)
# Out:
# [[  1   3   5   8]
#  [  0 -31 -57 -85]
#  [  0   0 -89  25]]

# %%
A4 = A3.copy()

# %%
A4[1,:] = -1/31*A4[1,:]
print (A4)
# Out:
# [[  1   3   5   8]
#  [  0   1   1   2]
#  [  0   0 -89  25]]

# %%
A4[2,:] = -(1/89)*A4[2,:]

# %%
print(A4)
# Out:
# [[1 3 5 8]
#  [0 1 1 2]
#  [0 0 1 0]]

# %%
A5 = A4.copy()

# %%
A5[1,:] = -1*A5[2,:] + A5[1,:]

# %%
print(A5)
# Out:
# [[1 3 5 8]
#  [0 1 0 2]
#  [0 0 1 0]]

# %%
A5[0,:] = -3*A5[1,:] + A5[0,:]

# %%
print(A5)
# Out:
# [[1 0 5 2]
#  [0 1 0 2]
#  [0 0 1 0]]

# %%
A5[0,:] = -5*A5[2,:] + A5[0,:]

# %%
print (A5)
# Out:
# [[1 0 5 2]
#  [0 1 0 2]
#  [0 0 1 0]]
