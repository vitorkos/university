# %%
import numpy as np

# %%
A = np.matrix('0.005, 2,4;3, 3.14,7;5,3,9')
print(A)
# Out:
# [[5.00e-03 2.00e+00 4.00e+00]
#  [3.00e+00 3.14e+00 7.00e+00]
#  [5.00e+00 3.00e+00 9.00e+00]]

# %%
Det_A = np.linalg.det(A)

# %%
Det_A
# Out:
# -10.763700000000004

# %%
from numpy.linalg import det

# %%
det(A)
# Out:
# -10.763700000000004
