# %%
import numpy as np

# %%
A = np.array([[2,1], [2,3]])

# %%
A
# Out:
# array([[2, 1],
#        [2, 3]])

# %%
B = np.array([[1,2,3],[4,5,6]])

# %%
B
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
C = np.matrix('1,2;4,4')

# %%
C
# Out:
# matrix([[1, 2],
#         [4, 4]])
